# %% [markdown]
# # Reading data

# %%
import pandas as pd

# %%
data_oceania = pd.read_csv("data/gapminder_gdp_oceania.csv")

# %%
print(data_oceania)
# Out:
#        country         1952         1957         1962         1967  \
# 0    Australia  10039.59564  10949.64959  12217.22686  14526.12465
# 1  New Zealand  10556.57566  12247.39532  13175.67800  14463.91893
#
#           1972         1977         1982         1987         1992  \
# 0  16788.62948  18334.19751  19477.00928  21888.88903  23424.76683
# 1  16046.03728  16233.71770  17632.41040  19007.19129  18363.32494
#
#           1997         2002         2007
# 0  26997.93657  30687.75473  34435.36744
# 1  21050.41377  23189.80135  25185.00911

# %%
#Indexing start at 0

# %%
#data type
print(type(data_oceania))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data_oceania.info() #Info function does not have arguments
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  2 non-null      object
#  1   1952     2 non-null      float64
#  2   1957     2 non-null      float64
#  3   1962     2 non-null      float64
#  4   1967     2 non-null      float64
#  5   1972     2 non-null      float64
#  6   1977     2 non-null      float64
#  7   1982     2 non-null      float64
#  8   1987     2 non-null      float64
#  9   1992     2 non-null      float64
#  10  1997     2 non-null      float64
#  11  2002     2 non-null      float64
#  12  2007     2 non-null      float64
# dtypes: float64(12), object(1)
# memory usage: 336.0+ bytes

# %%
print(data_oceania.dtypes)
# Out:
# country     object
# 1952       float64
# 1957       float64
# 1962       float64
# 1967       float64
# 1972       float64
# 1977       float64
# 1982       float64
# 1987       float64
# 1992       float64
# 1997       float64
# 2002       float64
# 2007       float64
# dtype: object

# %%
print(data_oceania.columns) #. means a variable of the DF
# Out:
# Index(['country', '1952', '1957', '1962', '1967', '1972', '1977', '1982',
#        '1987', '1992', '1997', '2002', '2007'],
#       dtype='object')

# %%
print(data_oceania.T)
# Out:
#                    0            1
# country    Australia  New Zealand
# 1952     10039.59564  10556.57566
# 1957     10949.64959  12247.39532
# 1962     12217.22686    13175.678
# 1967     14526.12465  14463.91893
# 1972     16788.62948  16046.03728
# 1977     18334.19751   16233.7177
# 1982     19477.00928   17632.4104
# 1987     21888.88903  19007.19129
# 1992     23424.76683  18363.32494
# 1997     26997.93657  21050.41377
# 2002     30687.75473  23189.80135
# 2007     34435.36744  25185.00911

# %%
transposed_data_ocenia = data_oceania.T

# %%
transposed_data_ocenia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, country to 2007
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       13 non-null     object
#  1   1       13 non-null     object
# dtypes: object(2)
# memory usage: 868.0+ bytes

# %%
data_europe = pd.read_csv("data/gapminder_gdp_europe.csv", index_col="country")

# %%
print(data_europe.loc["Albania","1952"])
#loc = piece of data
# Out:
# 1601.056136

# %%
print(data_europe.shape)
# Out:
# (30, 12)

# %%
print("first number in DF:", data_europe.iloc[0,0])
# Out:
# first number in DF: 1601.056136

# %%
print("Middle:", data_europe.iloc[14,5])
# Out:
# Middle: 11150.98113

# %%
print(data_europe.loc['Belgium':'Bulgaria','1957':'1987'])
# Out:
#                                1957          1962          1967          1972  \
# country
# Belgium                 9714.960623  10991.206760  13149.041190  16672.143560
# Bosnia and Herzegovina  1353.989176   1709.683679   2172.352423   2860.169750
# Bulgaria                3008.670727   4254.337839   5577.002800   6597.494398
#
#                                 1977          1982          1987
# country
# Belgium                 19117.974480  20979.845890  22525.563080
# Bosnia and Herzegovina   3528.481305   4126.613157   4314.114757
# Bulgaria                 7612.240438   8224.191647   8239.854824

# %%
print("All countries before and inc. Belgium for years 57-67") 
print(data_europe.loc[:'Belgium','1957':'1967'])
# Out:
# All countries before and inc. Belgium for years 57-67
#                 1957          1962          1967
# country
# Albania  1942.284244   2312.888958   2760.196931
# Austria  8842.598030  10750.721110  12834.602400
# Belgium  9714.960623  10991.206760  13149.041190

# %%
print("All countries from 2002 onwards")
print(data_europe.loc[:,"2002":])
# Out:
# All countries from 2002 onwards
#                                 2002          2007
# country
# Albania                  4604.211737   5937.029526
# Austria                 32417.607690  36126.492700
# Belgium                 30485.883750  33692.605080
# Bosnia and Herzegovina   6018.975239   7446.298803
# Bulgaria                 7696.777725  10680.792820
# Croatia                 11628.388950  14619.222720
# Czech Republic          17596.210220  22833.308510
# Denmark                 32166.500060  35278.418740
# Finland                 28204.590570  33207.084400
# France                  28926.032340  30470.016700
# Germany                 30035.801980  32170.374420
# Greece                  22514.254800  27538.411880
# Hungary                 14843.935560  18008.944440
# Iceland                 31163.201960  36180.789190
# Ireland                 34077.049390  40675.996350
# Italy                   27968.098170  28569.719700
# Montenegro               6557.194282   9253.896111
# ...

# %%
print(data_europe.loc["Italy",:])
# Out:
# 1952     4931.404155
# 1957     6248.656232
# 1962     8243.582340
# 1967    10022.401310
# 1972    12269.273780
# 1977    14255.984750
# 1982    16537.483500
# 1987    19207.234820
# 1992    22013.644860
# 1997    24675.024460
# 2002    27968.098170
# 2007    28569.719700
# Name: Italy, dtype: float64

# %%
print(data_europe.loc[:,'1982'])
# Out:
# country
# Albania                    3630.880722
# Austria                   21597.083620
# Belgium                   20979.845890
# Bosnia and Herzegovina     4126.613157
# Bulgaria                   8224.191647
# Croatia                   13221.821840
# Czech Republic            15377.228550
# Denmark                   21688.040480
# Finland                   18533.157610
# France                    20293.897460
# Germany                   22031.532740
# Greece                    15268.420890
# Hungary                   12545.990660
# Iceland                   23269.607500
# Ireland                   12618.321410
# Italy                     16537.483500
# Montenegro                11222.587620
# Netherlands               21399.460460
# Norway                    26298.635310
# Poland                     8451.531004
# Portugal                  11753.842910
# Romania                    9605.314053
# Serbia                    15181.092700
# Slovak Republic           11348.545850
# ...

# %%
print(data_europe.loc["Italy"])
# Out:
# 1952     4931.404155
# 1957     6248.656232
# 1962     8243.582340
# 1967    10022.401310
# 1972    12269.273780
# 1977    14255.984750
# 1982    16537.483500
# 1987    19207.234820
# 1992    22013.644860
# 1997    24675.024460
# 2002    27968.098170
# 2007    28569.719700
# Name: Italy, dtype: float64

# %%
print('First 4 countries, first 3 years', data_europe.iloc[0:4,0:3])
# Out:
# First 4 countries, first 3 years                                1952         1957          1962
# country
# Albania                 1601.056136  1942.284244   2312.888958
# Austria                 6137.076492  8842.598030  10750.721110
# Belgium                 8343.105127  9714.960623  10991.206760
# Bosnia and Herzegovina   973.533195  1353.989176   1709.683679

# %%
print(data_europe.iloc[0:2, 0:2]) #This is up to but not including 2
# Out:
#                 1952         1957
# country
# Albania  1601.056136  1942.284244
# Austria  6137.076492  8842.598030

# %%
print(data_europe.loc["Albania":"Belgium", "1952":"1962"]) #Up to and including
# Out:
#                 1952         1957          1962
# country
# Albania  1601.056136  1942.284244   2312.888958
# Austria  6137.076492  8842.598030  10750.721110
# Belgium  8343.105127  9714.960623  10991.206760

# %%
data_americas_country = pd.read_csv("data/gapminder_gdp_americas.csv", index_col = "country")

# %%
pd.read_csv("data/gapminder_gdp_americas.csv")
# Out:
#                 country          1952          1957          1962  \
# 0             Argentina   3758.523437   4245.256698   4957.037982
# 1               Bolivia   3112.363948  61729.977564  62612.716475
# 2                Brazil  52526.828538  52271.715538   2492.351109
# 3                Canada  80721.137366   2127.686326  72081.241665
# 4                 Chile   7689.799761   9802.466526   8422.974165
# 5              Colombia   2194.926204   2220.487682   2291.156835
# 6            Costa Rica   2480.380334   2961.800905  52557.508254
# 7                  Cuba   3478.125529  53439.098778   4581.609385
# 8    Dominican Republic   3522.110717   3780.546651   6766.936778
# 9               Ecuador  58463.737172   4315.622723   4519.094331
# 10          El Salvador  53800.299705   2487.365989   3336.585802
# 11            Guatemala  81010.076599  83776.637546   7133.166023
# 12                Haiti  13990.482080  14847.127120  16173.145860
# ...

# %%
print(data_americas_country.shape)
# Out:
# (25, 12)

# %%
data_americas_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  25 non-null     object
#  1   1952     25 non-null     float64
#  2   1957     25 non-null     float64
#  3   1962     25 non-null     float64
#  4   1967     25 non-null     float64
#  5   1972     25 non-null     float64
#  6   1977     25 non-null     float64
#  7   1982     25 non-null     float64
#  8   1987     25 non-null     float64
#  9   1992     25 non-null     float64
#  10  1997     25 non-null     float64
#  11  2002     25 non-null     float64
#  12  2007     25 non-null     float64
# dtypes: float64(12), object(1)
# memory usage: 2.7+ KB

# %%
data_americas_country.describe()
# Out:
#                1952          1957          1962          1967          1972  \
# count     25.000000     25.000000     25.000000     25.000000     25.000000
# mean   20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# std    29568.561177  26017.674581  26354.946134  25993.732153  23083.135977
# min     1397.717137   1544.402995   1662.137359   1452.057666   1654.456946
# 25%     2898.530881   2617.155967   4519.094331   4161.727834   5118.146939
# 50%     3522.110717   4245.256698   5246.107524   5754.733883   6619.551419
# 75%    13990.482080  46346.460607  16173.145860  19530.365570  29513.658556
# max    90971.848359  83776.637546  74736.768154  77446.825850  62829.875603
#
#                1977          1982          1987          1992          1997  \
# count     25.000000     25.000000     25.000000     25.000000     25.000000
# mean   20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# ...

# %%
data_europe.info?
# Out:
# Signature:
# data_europe.info(
#     verbose: 'bool | None' = None,
#     buf: 'WriteBuffer[str] | None' = None,
#     max_cols: 'int | None' = None,
#     memory_usage: 'bool | str | None' = None,
#     show_counts: 'bool | None' = None,
#     null_counts: 'bool | None' = None,
# ) -> 'None'
# Docstring:
# Print a concise summary of a DataFrame.
#
# This method prints information about a DataFrame including
# the index dtype and columns, non-null values and memory usage.
#
# Parameters
# ----------
# verbose : bool, optional
#     Whether to print the full summary. By default, the setting in
#     ``pandas.options.display.max_info_columns`` is followed.
# buf : writable buffer, defaults to sys.stdout
#     Where to send the output. By default, the output is printed to
#     sys.stdout. Pass a writable buffer if you need to further process
#     the output.    max_cols : int, optional
#     When to switch from the verbose to the truncated output. If the
# ...

# %%
help(data_americas_country.head)
# Out:
# Help on method head in module pandas.core.generic:
#
# head(n: 'int' = 5) -> 'NDFrameT' method of pandas.core.frame.DataFrame instance
#     Return the first `n` rows.
#
#     This function returns the first `n` rows for the object based
#     on position. It is useful for quickly testing if your object
#     has the right type of data in it.
#
#     For negative values of `n`, this function returns all rows except
#     the last `|n|` rows, equivalent to ``df[:n]``.
#
#     If n is larger than the number of rows, this function returns all rows.
#
#     Parameters
#     ----------
#     n : int, default 5
#         Number of rows to select.
#
#     Returns
#     -------
#     same type as caller
#         The first `n` rows of the caller object.
#
#     See Also
#     --------
#     DataFrame.tail: Returns the last `n` rows.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame({'animal': ['alligator', 'bee', 'falcon', 'lion',
# ...

# %%
data_americas_country.head(3)
# Out:
#                    1952          1957          1962          1967  \
# country
# Argentina   3758.523437   4245.256698   4957.037982  77446.825850
# Bolivia     3112.363948  61729.977564  62612.716475   4643.393534
# Brazil     52526.828538  52271.715538   2492.351109   2678.729839
#
#                    1972         1977          1982          1987         1992  \
# country
# Argentina   5937.827283  6281.290855   6434.501797   6360.943444  4446.380924
# Bolivia     4688.593267  5486.371089   3470.338156  48502.998326  2170.151724
# Brazil     59550.767795  3815.807870  44440.084992   7076.478233  5444.648617
#
#                   1997          2002          2007
# country
# Argentina  5838.347657  53731.890130  38648.379084
# Bolivia    2253.023004   2474.548819   2749.320965
# Brazil     6117.361746  45726.614039   7006.580419

# %%
data_americas_country.tail(n=3)
# Out:
#                       1952         1957          1962          1967  \
# country
# United States  2428.237769  2617.155967  68971.672032  60114.541083
# Uruguay        5716.766744  6150.772969   5603.357717   5444.619620
# Venezuela      3048.302900  3421.523218   3776.803627   4358.595393
#
#                        1972         1977         1982          1987  \
# country
# United States   4031.408271  4879.992748  4820.494790   4246.485974
# Uruguay         5703.408898  6504.339663  6920.223051  52329.603891
# Venezuela      29513.658556  5138.922374  4098.344175   4140.442097
#
#                       1992         1997          2002          2007
# country
# United States  4439.450840  4684.313807  48053.197869   5186.050003
# Uruguay        8137.004775  9230.240708   7727.002004  10611.462990
# Venezuela      4444.231700  5154.825496  50742.767364   5728.353514

# %%
flip_americas = data_americas_country.T

# %%
flip_americas.tail(n=3).T
# Out:
#                              1997          2002          2007
# country
# Argentina             5838.347657  53731.890130  38648.379084
# Bolivia               2253.023004   2474.548819   2749.320965
# Brazil                6117.361746  45726.614039   7006.580419
# Canada               47416.219133   3413.262690   3822.137084
# Chile                10165.495180   8605.047831  51580.843077
# Colombia              3160.454906   3099.728660   3548.330846
# Costa Rica           44149.356043   7356.031934   9809.185636
# Cuba                 29732.575803  10742.440530  11977.574960
# Dominican Republic    7429.455877   5773.044512  36757.420700
# Ecuador              10118.053180  10778.783850  13171.638850
# El Salvador           7957.980824   8131.212843   9065.800825
# Guatemala            10967.281950   8797.640716  12779.379640
# Haiti                35767.433030  39097.099550  42951.653090
# Honduras             40649.765076   4563.808154   6025.374752
# ...

# %%
data_americas_country.T.tail(n=3).T
# Out:
#                              1997          2002          2007
# country
# Argentina             5838.347657  53731.890130  38648.379084
# Bolivia               2253.023004   2474.548819   2749.320965
# Brazil                6117.361746  45726.614039   7006.580419
# Canada               47416.219133   3413.262690   3822.137084
# Chile                10165.495180   8605.047831  51580.843077
# Colombia              3160.454906   3099.728660   3548.330846
# Costa Rica           44149.356043   7356.031934   9809.185636
# Cuba                 29732.575803  10742.440530  11977.574960
# Dominican Republic    7429.455877   5773.044512  36757.420700
# Ecuador              10118.053180  10778.783850  13171.638850
# El Salvador           7957.980824   8131.212843   9065.800825
# Guatemala            10967.281950   8797.640716  12779.379640
# Haiti                35767.433030  39097.099550  42951.653090
# Honduras             40649.765076   4563.808154   6025.374752
# ...

# %%
americas_columns = data_americas_country.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 americas_columns = data_americas_country.shape()
#
# TypeError: 'tuple' object is not callable

# %%
element = 'oxygen'
element[3:3]
# Out:
# ''

# %%
data_europe.iloc[5:5,4:4] #Just produce the label
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
a = pd.read_csv("data/gapminder_gdp_americas.csv", )

# %%
a.iloc[5:5,4:4]
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data_europe.iloc[3:3,:]

#Print number of columns
#.info VS help
#what is the meaning of .
#When "up to and including?"
# Out:
# Empty DataFrame
# Columns: [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007]
# Index: []
